# %%
from tkinter import *
import urllib.request
# import requests
# from tkinter import *
# from pytube import YouTube
import pandas as pd
import numpy as np
import bs4

win = Tk()
win.geometry("420x320")
win.title("Website Downloader")

# logo = PhotoImage(file="logo.jpg")
# win.iconphoto(False,logo)

Label(win,text='Website downloader',font=('Arial 20 bold'),bg="lightgreen").pack(padx=5,pady=50)

v_link = StringVar()
Label(win,text='Enter the link: ',font=("Arial",20,"bold")).place(x=120,y=110)
Entry_link = Entry(win,width=34,font=20,textvariable=v_link,bd=4).place(x=20,y=150)

def v_download():
    v_url = urllib.request.urlopen(str(v_link))
    videos = v_url.read()
    print(videos)
    
    Label(win,text="Download completed...",font=("Arial",18,"bold"),bg="lightyellow",fg="black").place(x=100,y=250)
    Label(win,text="Check out your download video in the folder.....").place(x=100,y=300)
    
    
    
Button(win,text="Download",font=("Arial",20,"bold"),bg="lightgrey",command=v_download).place(x=140,y=200)

win.mainloop()

# %%
import urllib.request
import bs4
import numpy as np
import pandas as pd
url = 'http://www.read4bca.com'
beauty = urllib.request.urlopen(url).read()
# beauty
soup = bs4.BeautifulSoup(beauty)
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <head>
#   <title>
#    Read4bca
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#   <link href="assets/css/main.css" rel="stylesheet"/>
#   <noscript>
#    <link href="assets/css/noscript.css" rel="stylesheet"/>
#   </noscript>
#   <meta content="Thapar Institute of Engineering &amp; Technology MCA, Himcahal Pradesh University BCA Notes Available Here" name="description"/>
#   <meta content="Read4bca, Himcahal Pradesh University, HPU, Previous Year question papers of BCA, read4bca, Previous Year question papers of Numerical Methods, Previous Year question papers of Computer Graphics, Previous Year question papers of Computer Networking, Previous Year question papers of Software Engineering" name="keywords"/>
#   <meta content="2D92A30C8236EA2B36D72E170D4B8A18" name="msvalidate.01">
#    <meta content="d71sKvaMgGwiaqe07u7724wnQQASXosBQbbxeib9sMA" name="google-site-verification"/>
#    <link href="images/favicon.png" rel="shortcut icon" type="image/png"/>
#    <!-- Global site tag (gtag.js) - Google Analytics -->
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-140459898-1">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-140459898-1');
#    </script>
#   </meta>
#  </head>
#  <body class="is-preload">
#   <!-- Wrapper -->
#   <div id="page-wrapper">
#    <!-- Wrapper -->
#    <div id="wrapper">
#     <!-- Panel (Banner) -->
#     <section class="panel banner right">
#      <div class="content color0 span-3-75">
#       <h1 class="major">
#        Hello, my name
#        <br/>
#        is Robin
#       </h1>
#       <p>
#        The study material for MCA 1st Semester/ BCA 6th Semester are available below
#        <br/>
#        Download and Enjoy
#       </p>
#      </div>
#      <div class="image filtered span-1-75" data-position="25% 25%">
#       <img alt="" src="images/robin.jpg"/>
#      </div>
#     </section>
#    </div>
#   </div>
#   <!-- Main -->
#   <div id="main">
#    <!-- Posts -->
#    <section class="posts">
#     <article>
#      <h2>
#       MCA
#      </h2>
#      <a class="image fit" href="#">
#       <img alt="Numerical Methods" src="images/Operating System.jpeg"/>
#      </a>
#      <p>
#       <a href="assets/pdfs/Unix Concepts and Applications by Robin Singh.pdf" target="_blank">
#        Notes of UNIX By Robin
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Unix Concepts and Applications Notes by Abhinav.pdf" target="_blank">
#        Written Notes by Abhinav
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/unix.pdf" target="_blank">
#        Unix Concepts and Applications (Sumitabha Das)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/unix_ppt.pdf" target="_blank">
#        Unix PPT
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#     </article>
#     <article>
#      <h2>
#       BCA
#      </h2>
#      <a class="image fit" href="#">
#       <img alt="Numerical Methods" src="images/Numerical Methods.png"/>
#      </a>
#      <p>
#       <a href="assets/pdfs/Previous Year (2018) Question Paper of Numerical Methods BCA-0602.pdf">
#        Question Paper of Numerical Methods 2018
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2019) Question Paper of Numerical Methods BCA-0602.pdf">
#        Question Paper of Numerical Methods 2019
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous year 2020 question paper of numerical methods.pdf">
#        Question Paper of Numerical Methods 2020
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#     </article>
#     <article>
#      <h2>
#       BCA
#      </h2>
#      <a class="image fit" href="">
#       <img alt="Computer Networks" src="images/Computer Networking.png"/>
#      </a>
#      <p>
#       <a href="assets/pdfs/Computer Networks.pdf">
#        Notes of Computer Networks By Robin
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2019) Question Paper of Computer Networks BCA-0601.pdf">
#        Previous Year Question paper of Computer Networks(2019)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous year 2020 question paper of Computer Networks.pdf">
#        Previous Year Question paper of Computer Networks(2020)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#     </article>
#     <article>
#      <h2>
#       BCA
#      </h2>
#      <a class="image fit" href="#">
#       <img alt="Multimedia Technology" src="images/Multimedia Technology.png"/>
#      </a>
#      <p>
#       <a href="assets/pdfs/Multimedia Technology.pdf">
#        Notes of Multimedia Technology By Robin
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2018) Question Paper of Multimedia Technology BCA-0603.pdf">
#        Previous Year Question paper of Multimedia Technology(2018)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous year 2020 question paper of Multimedia Texhnology.pdf">
#        Previous Year Question paper of Multimedia Technology(2020)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#     </article>
#     <article>
#      <h2>
#       BCA
#      </h2>
#      <a class="image fit" href="#">
#       <img alt="Computer graphics" src="images/Computer Graphics.png"/>
#      </a>
#      <p>
#       <a href="assets/pdfs/Computer Graphics BCA0604.pdf">
#        Notes of Computer Graphics By Robin
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2018) Question Paper of Computer Graphics BCA-0604.pdf">
#        Previous Year Question paper of Computer Networks(2018)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2019) Question Paper of Computer Graphics BCA-0604.pdf">
#        Previous Year Question paper of Computer Networks(2019)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous year 2020 question paper of Computer Graphics.pdf">
#        Previous Year Question paper of Computer Networks(2020)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#     </article>
#     <article>
#      <h2>
#       BCA
#      </h2>
#      <a class="image fit" href="#">
#       <img alt="Software engineering" src="images/software engineering.jpg"/>
#      </a>
#      <p>
#       <a href="assets/pdfs/Software Engineering BCA0605.pdf">
#        Notes of Software engineering By Robin
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2018) Question Paper of Software Engineering BCA-0605.pdf">
#        Previous Year Question paper of Software engineering(2018)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous Year (2019) Question Paper of Software Engineering BCA-0605.pdf">
#        Previous Year Question paper of Software engineering(2019)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#      <p>
#       <a href="assets/pdfs/Previous year 2020 question paper of software engineering.pdf">
#        Previous Year Question paper of Software engineering(2020)
#        <bold class="download">
#         Download
#        </bold>
#       </a>
#      </p>
#     </article>
#     <article>
#     </article>
#    </section>
#    <!-- Footer -->
#    <footer>
#     <div class="pagination">
#      <!--<a href="#" class="previous">Prev</a>-->
#      <a class="page active" href="#">
#       1
#      </a>
#      <a class="next" href="#">
#       End
#      </a>
#     </div>
#    </footer>
#   </div>
#   <!-- Footer -->
#   <footer id="footer">
#    <section>
#     <form action="#" method="post">
#      <div class="fields">
#       <div class="field">
#        <label for="name">
#         Name
#        </label>
#        <input id="name" name="name" type="text"/>
#       </div>
#       <div class="field">
#        <label for="email">
#         Email
#        </label>
#        <input id="email" name="email" type="text"/>
#       </div>
#       <div class="field">
#        <label for="message">
#         Message
#        </label>
#        <textarea id="message" name="message" rows="3"></textarea>
#       </div>
#      </div>
#      <ul class="actions">
#       <li>
#        <input type="submit" value="Send Message"/>
#       </li>
#      </ul>
#     </form>
#    </section>
#    <section class="split contact">
#     <section class="alt">
#      <h3>
#       Address
#      </h3>
#      <p>
#       Himcahal Pradesh, India
#      </p>
#     </section>
#     <section>
#      <h3>
#       Phone
#      </h3>
#      <p>
#       <a href="#">
#        +91 8894358978
#       </a>
#      </p>
#     </section>
#     <section>
#      <h3>
#       Email
#      </h3>
#      <p>
#       <a href="#">
#        robin.007660@gmail.com
#       </a>
#      </p>
#     </section>
#     <section>
#      <h3>
#       Social
#      </h3>
#      <ul class="icons alt">
#       <li>
#        <a class="icon brands alt fa-instagram" href="https://www.instagram.com/robin7852/">
#         <span class="label">
#          Instagram
#         </span>
#        </a>
#       </li>
#      </ul>
#     </section>
#    </section>
#   </footer>
#   <!-- Copyright -->
#   <div id="copyright">
#    <ul>
#     <li>
#      By Robin Singh
#     </li>
#    </ul>
#   </div>
#   <!-- Scripts -->
#   <script src="assets/js/jquery.min.js">
#   </script>
#   <script src="assets/js/jquery.scrollex.min.js">
#   </script>
#   <script src="assets/js/jquery.scrolly.min.js">
#   </script>
#   <script src="assets/js/browser.min.js">
#   </script>
#   <script src="assets/js/breakpoints.min.js">
#   </script>
#   <script src="assets/js/util.js">
#   </script>
#   <script src="assets/js/main.js">
#   </script>
#  </body>
#  <script>
#   'undefined'=== typeof _trfq || (window._trfq = []);'undefined'=== typeof _trfd && (window._trfd=[]),_trfd.push({'tccl.baseHost':'secureserver.net'}),_trfd.push({'ap':'cpsh-oh'},{'server':'sg2plzcpnl490047'},{'id':'8465976'}) // Monitoring performance to make your website faster. If you want to opt-out, please contact web hosting support.
#  </script>
#  <script src="https://img1.wsimg.com/tcc/tcc_l.combined.1.0.6.min.js">
#  </script>
# </html>

# %%
print(soup.h1.prettify())
# Out:
# <h1 class="major">
#  Hello, my name
#  <br/>
#  is Robin
# </h1>

# %%
print(soup.head.contents)
# Out:
# ['\n', <title>Read4bca</title>, '\n', <meta charset="utf-8"/>, '\n', <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>, '\n', <link href="assets/css/main.css" rel="stylesheet"/>, '\n', <noscript><link href="assets/css/noscript.css" rel="stylesheet"/></noscript>, '\n', <meta content="Thapar Institute of Engineering &amp; Technology MCA, Himcahal Pradesh University BCA Notes Available Here" name="description"/>, '\n', <meta content="Read4bca, Himcahal Pradesh University, HPU, Previous Year question papers of BCA, read4bca, Previous Year question papers of Numerical Methods, Previous Year question papers of Computer Graphics, Previous Year question papers of Computer Networking, Previous Year question papers of Software Engineering" name="keywords"/>, '\n', <meta content="2D92A30C8236EA2B36D72E170D4B8A18" name="msvalidate.01">
# <meta content="d71sKvaMgGwiaqe07u7724wnQQASXosBQbbxeib9sMA" name="google-site-verification"/>
# <link href="images/favicon.png" rel="shortcut icon" type="image/png"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-140459898-1"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-140459898-1');
# </script>
# </meta>]

# %%
x = soup.head.title.string
print(x)
# Out:
# Read4bca

# %%
for child in soup.head.descendants:
    print(child)
# Out:
# <title>Read4bca</title>
# Read4bca
#
#
# <meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#
#
# <link href="assets/css/main.css" rel="stylesheet"/>
#
#
# <noscript><link href="assets/css/noscript.css" rel="stylesheet"/></noscript>
# <link href="assets/css/noscript.css" rel="stylesheet"/>
#
#
# <meta content="Thapar Institute of Engineering &amp; Technology MCA, Himcahal Pradesh University BCA Notes Available Here" name="description"/>
#
#
# <meta content="Read4bca, Himcahal Pradesh University, HPU, Previous Year question papers of BCA, read4bca, Previous Year question papers of Numerical Methods, Previous Year question papers of Computer Graphics, Previous Year question papers of Computer Networking, Previous Year question papers of Software Engineering" name="keywords"/>
#
#
# <meta content="2D92A30C8236EA2B36D72E170D4B8A18" name="msvalidate.01">
# <meta content="d71sKvaMgGwiaqe07u7724wnQQASXosBQbbxeib9sMA" name="google-site-verification"/>
# <link href="images/favicon.png" rel="shortcut icon" type="image/png"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-140459898-1"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-140459898-1');
# </script>
# </meta>
#
#
# <meta content="d71sKvaMgGwiaqe07u7724wnQQASXosBQbbxeib9sMA" name="google-site-verification"/>
#
#
# <link href="images/favicon.png" rel="shortcut icon" type="image/png"/>
#
#
#  Global site tag (gtag.js) - Google Analytics
#
#
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-140459898-1"></script>
#
#
# <script>
#         window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-140459898-1');
# </script>
#
#         window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-140459898-1');

# %%
for string in soup.strings:
    print(repr(string))
# Out:
# '\n'
# '\n'
# '\n'
# 'Read4bca'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'Hello, my name'
# '\r\n\t\t\t\t\t\t\t\tis Robin'
# '\n'
# 'The study material for MCA 1st Semester/ BCA 6th Semester are available below\r\n\t\t\t\t\t\t\t\t'
# ' Download and Enjoy'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'MCA'
# '\n'
# '\n'
# 'Notes of UNIX By Robin '
# 'Download'
# '\n'
# 'Written Notes by Abhinav '
# 'Download'
# '\n'
# 'Unix Concepts and Applications (Sumitabha Das) '
# 'Download'
# '\n'
# 'Unix PPT '
# 'Download'
# '\n'
# '\n'
# '\n'
# 'BCA'
# '\n'
# '\n'
# 'Question Paper of Numerical Methods 2018 '
# 'Download'
# '\n'
# 'Question Paper of Numerical Methods 2019 '
# 'Download'
# '\n'
# 'Question Paper of Numerical Methods 2020 '
# 'Download'
# '\n'
# '\n'
# '\n'
# 'BCA'
# '\n'
# '\n'
# 'Notes of Computer Networks By Robin '
# 'Download'
# '\n'
# 'Previous Year Question paper of Computer Networks(2019) '
# 'Download'
# '\n'
# 'Previous Year Question paper of Computer Networks(2020) '
# 'Download'
# '\n'
# '\n'
# '\n'
# 'BCA'
# '\n'
# '\n'
# 'Notes of Multimedia Technology By Robin '
# 'Download'
# '\n'
# 'Previous Year Question paper of Multimedia Technology(2018) '
# 'Download'
# '\n'
# 'Previous Year Question paper of Multimedia Technology(2020) '
# 'Download'
# '\n'
# '\n'
# '\n'
# 'BCA'
# '\n'
# '\n'
# 'Notes of Computer Graphics By Robin '
# 'Download'
# '\n'
# 'Previous Year Question paper of Computer Networks(2018) '
# 'Download'
# '\n'
# 'Previous Year Question paper of Computer Networks(2019) '
# 'Download'
# '\n'
# 'Previous Year Question paper of Computer Networks(2020) '
# 'Download'
# '\n'
# '\n'
# '\n'
# 'BCA'
# '\n'
# '\n'
# 'Notes of Software engineering By Robin '
# 'Download'
# '\n'
# 'Previous Year Question paper of Software engineering(2018) '
# 'Download'
# '\n'
# 'Previous Year Question paper of Software engineering(2019) '
# 'Download'
# '\n'
# 'Previous Year Question paper of Software engineering(2020) '
# 'Download'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '1'
# '\n'
# 'End'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'Name'
# '\n'
# '\n'
# '\n'
# '\n'
# 'Email'
# '\n'
# '\n'
# '\n'
# '\n'
# 'Message'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'Address'
# '\n'
# 'Himcahal Pradesh, India'
# '\n'
# '\n'
# '\n'
# 'Phone'
# '\n'
# '+91 8894358978'
# '\n'
# '\n'
# '\n'
# 'Email'
# '\n'
# 'robin.007660@gmail.com'
# '\n'
# '\n'
# '\n'
# 'Social'
# '\n'
# '\n'
# 'Instagram'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# 'By Robin Singh'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'
# '\n'

# %%
y = soup.get_text()
print(y)
# Out:
# Read4bca
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hello, my name
# 								is Robin
# The study material for MCA 1st Semester/ BCA 6th Semester are available below
# 								 Download and Enjoy
#
#
#
#
#
#
#
#
#
#
#
#
# MCA
#
# Notes of UNIX By Robin Download
# Written Notes by Abhinav Download
# Unix Concepts and Applications (Sumitabha Das) Download
# Unix PPT Download
#
#
# BCA
#
# Question Paper of Numerical Methods 2018 Download
# Question Paper of Numerical Methods 2019 Download
# Question Paper of Numerical Methods 2020 Download
#
#
# BCA
#
# Notes of Computer Networks By Robin Download
# Previous Year Question paper of Computer Networks(2019) Download
# Previous Year Question paper of Computer Networks(2020) Download
#
#
# BCA
#
# Notes of Multimedia Technology By Robin Download
# Previous Year Question paper of Multimedia Technology(2018) Download
# Previous Year Question paper of Multimedia Technology(2020) Download
#
#
# BCA
#
# Notes of Computer Graphics By Robin Download
# Previous Year Question paper of Computer Networks(2018) Download
# Previous Year Question paper of Computer Networks(2019) Download
# Previous Year Question paper of Computer Networks(2020) Download
#
#
# BCA
#
# Notes of Software engineering By Robin Download
# Previous Year Question paper of Software engineering(2018) Download
# Previous Year Question paper of Software engineering(2019) Download
# Previous Year Question paper of Software engineering(2020) Download
#
#
#
#
#
#
#
# 1
# End
#
#
#
#
#
#
#
#
#
# Name
#
#
#
# Email
#
#
#
# Message
#
#
#
#
#
#
#
#
#
#
# Address
# Himcahal Pradesh, India
#
#
# Phone
# +91 8894358978
#
#
# Email
# robin.007660@gmail.com
#
#
# Social
#
# Instagram
#
#
#
#
#
#
# By Robin Singh

# %%
soup.findAll('a')
# Out:
# [<a class="image fit" href="#"><img alt="Numerical Methods" src="images/Operating System.jpeg"/></a>,
#  <a href="assets/pdfs/Unix Concepts and Applications by Robin Singh.pdf" target="_blank">Notes of UNIX By Robin <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Unix Concepts and Applications Notes by Abhinav.pdf" target="_blank">Written Notes by Abhinav <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/unix.pdf" target="_blank">Unix Concepts and Applications (Sumitabha Das) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/unix_ppt.pdf" target="_blank">Unix PPT <bold class="download">Download</bold></a>,
#  <a class="image fit" href="#"><img alt="Numerical Methods" src="images/Numerical Methods.png"/></a>,
#  <a href="assets/pdfs/Previous Year (2018) Question Paper of Numerical Methods BCA-0602.pdf">Question Paper of Numerical Methods 2018 <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2019) Question Paper of Numerical Methods BCA-0602.pdf">Question Paper of Numerical Methods 2019 <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous year 2020 question paper of numerical methods.pdf">Question Paper of Numerical Methods 2020 <bold class="download">Download</bold></a>,
#  <a class="image fit" href=""><img alt="Computer Networks" src="images/Computer Networking.png"/></a>,
#  <a href="assets/pdfs/Computer Networks.pdf">Notes of Computer Networks By Robin <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2019) Question Paper of Computer Networks BCA-0601.pdf">Previous Year Question paper of Computer Networks(2019) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous year 2020 question paper of Computer Networks.pdf">Previous Year Question paper of Computer Networks(2020) <bold class="download">Download</bold></a>,
#  <a class="image fit" href="#"><img alt="Multimedia Technology" src="images/Multimedia Technology.png"/></a>,
#  <a href="assets/pdfs/Multimedia Technology.pdf">Notes of Multimedia Technology By Robin <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2018) Question Paper of Multimedia Technology BCA-0603.pdf">Previous Year Question paper of Multimedia Technology(2018) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous year 2020 question paper of Multimedia Texhnology.pdf">Previous Year Question paper of Multimedia Technology(2020) <bold class="download">Download</bold></a>,
#  <a class="image fit" href="#"><img alt="Computer graphics" src="images/Computer Graphics.png"/></a>,
#  <a href="assets/pdfs/Computer Graphics BCA0604.pdf">Notes of Computer Graphics By Robin <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2018) Question Paper of Computer Graphics BCA-0604.pdf">Previous Year Question paper of Computer Networks(2018) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2019) Question Paper of Computer Graphics BCA-0604.pdf">Previous Year Question paper of Computer Networks(2019) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous year 2020 question paper of Computer Graphics.pdf">Previous Year Question paper of Computer Networks(2020) <bold class="download">Download</bold></a>,
#  <a class="image fit" href="#"><img alt="Software engineering" src="images/software engineering.jpg"/></a>,
#  <a href="assets/pdfs/Software Engineering BCA0605.pdf">Notes of Software engineering By Robin <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2018) Question Paper of Software Engineering BCA-0605.pdf">Previous Year Question paper of Software engineering(2018) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous Year (2019) Question Paper of Software Engineering BCA-0605.pdf">Previous Year Question paper of Software engineering(2019) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Previous year 2020 question paper of software engineering.pdf">Previous Year Question paper of Software engineering(2020) <bold class="download">Download</bold></a>,
#  <a class="page active" href="#">1</a>,
#  <a class="next" href="#">End</a>,
#  <a href="#">+91 8894358978</a>,
#  <a href="#">robin.007660@gmail.com</a>,
#  <a class="icon brands alt fa-instagram" href="https://www.instagram.com/robin7852/"><span class="label">Instagram</span></a>]

# %%
soup.findAll('a',limit=5)
# Out:
# [<a class="image fit" href="#"><img alt="Numerical Methods" src="images/Operating System.jpeg"/></a>,
#  <a href="assets/pdfs/Unix Concepts and Applications by Robin Singh.pdf" target="_blank">Notes of UNIX By Robin <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/Unix Concepts and Applications Notes by Abhinav.pdf" target="_blank">Written Notes by Abhinav <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/unix.pdf" target="_blank">Unix Concepts and Applications (Sumitabha Das) <bold class="download">Download</bold></a>,
#  <a href="assets/pdfs/unix_ppt.pdf" target="_blank">Unix PPT <bold class="download">Download</bold></a>]

# %%
soup.findAll(text = 'Download')
# Out:
# ['Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download',
#  'Download']

# %%
soup.find_all('a')[1].get('href')
# Out:
# 'assets/pdfs/Unix Concepts and Applications by Robin Singh.pdf'

# %%
z = [i.get('href') for i in soup.findAll('a',limit = 100)]

# %%
print(z)
# Out:
# ['#', 'assets/pdfs/Unix Concepts and Applications by Robin Singh.pdf', 'assets/pdfs/Unix Concepts and Applications Notes by Abhinav.pdf', 'assets/pdfs/unix.pdf', 'assets/pdfs/unix_ppt.pdf', '#', 'assets/pdfs/Previous Year (2018) Question Paper of Numerical Methods BCA-0602.pdf', 'assets/pdfs/Previous Year (2019) Question Paper of Numerical Methods BCA-0602.pdf', 'assets/pdfs/Previous year 2020 question paper of numerical methods.pdf', '', 'assets/pdfs/Computer Networks.pdf', 'assets/pdfs/Previous Year (2019) Question Paper of Computer Networks BCA-0601.pdf', 'assets/pdfs/Previous year 2020 question paper of Computer Networks.pdf', '#', 'assets/pdfs/Multimedia Technology.pdf', 'assets/pdfs/Previous Year (2018) Question Paper of Multimedia Technology BCA-0603.pdf', 'assets/pdfs/Previous year 2020 question paper of Multimedia Texhnology.pdf', '#', 'assets/pdfs/Computer Graphics BCA0604.pdf', 'assets/pdfs/Previous Year (2018) Question Paper of Computer Graphics BCA-0604.pdf', 'assets/pdfs/Previous Year (2019) Question Paper of Computer Graphics BCA-0604.pdf', 'assets/pdfs/Previous year 2020 question paper of Computer Graphics.pdf', '#', 'assets/pdfs/Software Engineering BCA0605.pdf', 'assets/pdfs/Previous Year (2018) Question Paper of Software Engineering BCA-0605.pdf', 'assets/pdfs/Previous Year (2019) Question Paper of Software Engineering BCA-0605.pdf', 'assets/pdfs/Previous year 2020 question paper of software engineering.pdf', '#', '#', '#', '#', 'https://www.instagram.com/robin7852/']
